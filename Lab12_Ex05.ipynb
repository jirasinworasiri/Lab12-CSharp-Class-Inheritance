// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ในการทดลองนี้ จะได้ศึกษาลำดับของการทำงานของคลาสในการสืบทอดสมบัติ
//
// โดยให้คอนสตรักเตอร์ของคลาสแต่ละระดับทำหน้าที่แสดงข้อความออกมาตามบลำดับการสร้าง object

// %% [markdown]
// ## แผนผังการสืบทอดสมบัติของคลาส

// %%
classDiagram
    class BaseClass1
    class BaseClass2
    class DerivedClass

    BaseClass1 <|-- DerivedClass
    BaseClass2 <|-- DerivedClass
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="8e829401097d4165b5d0315ea3746925"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('8e829401097d4165b5d0315ea3746925');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_8e829401097d4165b5d0315ea3746925',
//                     `classDiagram
//     class BaseClass1
//     class BaseClass2
//     class DerivedClass
//
//     BaseClass1 <|-- DerivedClass
//     BaseClass2 <|-- DerivedClass
//     `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
// ...

// %% [markdown]
// จากแผนภาพคลาสไดอะแกรมด้านบน เราสามารถนำมาเขียนโปรแกรมในภาษา C# ได้ดังนี้

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex04
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// class BaseClass1
//  {
//     public BaseClass1()
//     {
//         System.Console.WriteLine("This is BaseClass1");
//     }
//  }
// class BaseClass2
//  {
//     public BaseClass2()
//     {
//         System.Console.WriteLine("This is BaseClass2");
//     }
//  }
//
// class DerivedClass : BaseClass1, BaseClass2
// {
//     public DerivedClass()
//     {
//         System.Console.WriteLine("This is DerivedClass");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex04
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex04
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// BaseClass1 และ BaseClass2 เป็นคลาสที่มีคอนสตรัคเตอร์ที่แสดงข้อความเมื่อสร้างอ็อบเจ็กต์.
//
// IBaseClass2 เป็น Interface ที่ให้ DerivedClass ใช้ฟังก์ชันจาก BaseClass2.
//
// DerivedClass สืบทอดจาก BaseClass1 และ "implement" (หรือใช้) IBaseClass2 เพื่อเข้าถึงฟังก์ชันจาก BaseClass2.

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. ในภาษา C#  เราสามารถสืบทอดสมบัติจาก Base class มากกว่าหนึ่งคลาสได้หรือไม่

// %% [markdown]
// C# ไม่รองรับการ multiple inheritance จากหลายคลาสโดยตรง

// %% [markdown]
// 2. จากข้อ 1 ถ้าไม่ได้แล้ว ในกรณีที่ต้องการสืบทอดจา่กหลาย Type จะทำได้อย่างไร

// %% [markdown]
// สามารถใช้ Interfaces หลายๆ ตัวในคลาสเดียวได้เพื่อให้คลาสนั้นสามารถใช้ฟังก์ชันจากหลาย type (หรือหลายคลาส) ได้
