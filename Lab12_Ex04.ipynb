// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ในการทดลองนี้ จะได้ศึกษาลำดับของการทำงานของคลาสในการสืบทอดสมบัติ
//
// โดยให้คอนสตรักเตอร์ของคลาสแต่ละระดับทำหน้าที่แสดงข้อความออกมาตามบลำดับการสร้าง object

// %% [markdown]
// ## แผนผังการสืบทอดสมบัติของคลาส

// %%
classDiagram
    class BaseClass1
    class BaseClass2
    class DerivedClass

    BaseClass2 <|-- DerivedClass
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="b5519beee9ce4f01b43546e2cf0a22ce"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('b5519beee9ce4f01b43546e2cf0a22ce');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_b5519beee9ce4f01b43546e2cf0a22ce',
//                     `classDiagram
//     class BaseClass1
//     class BaseClass2
//     class DerivedClass
//
//     BaseClass2 <|-- DerivedClass
//     `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// ...

// %% [markdown]
// จากแผนภาพคลาสไดอะแกรมด้านบน เราสามารถนำมาเขียนโปรแกรมในภาษา C# ได้ดังนี้

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex04
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// class BaseClass1
//  {
//     public BaseClass1()
//     {
//         System.Console.WriteLine("This is BaseClass1");
//     }
//  }
// class BaseClass2
//  {
//     public BaseClass2()
//     {
//         System.Console.WriteLine("This is BaseClass2");
//     }
//  }
//
// class DerivedClass : BaseClass2
// {
//     public DerivedClass()
//     {
//         System.Console.WriteLine("This is DerivedClass");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex04
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex04
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// Constructor ของคลาสแม่ (BaseClass2) ถูกเรียกก่อน
// เนื่องจาก DerivedClass สืบทอด (inherit) มาจาก BaseClass2
//
// ในการสร้างอ็อบเจ็กต์ของ DerivedClass ระบบจะต้องสร้างอ็อบเจ็กต์ของ BaseClass2 ก่อน

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. การที่มีคลาส BaseClass1 อยู่ใน source code นั้นมีผลใดๆ ต่อการทำงานของโปรแกรมหรือไม่

// %% [markdown]
// คลาส BaseClass1 ไม่มีผลต่อการทำงานของโปรแกรม เพราะมันไม่ได้ถูกใช้งานที่ไหนเลยในโค้ด

// %% [markdown]
// 2. ให้บอกลำดับการทำงานของคลาส ว่า constructor มีลำดับการเรียกอย่างไร (เรียก base class หรือ derive class ก่่อน)

// %% [markdown]
// เรียก Constructor ของ BaseClass2 ก่อน (เพราะ DerivedClass สืบทอด (inherit) จาก BaseClass2)
//
// เรียก Constructor ของ DerivedClass ทีหลัง
