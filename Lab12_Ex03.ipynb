// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ในการทดลองนี้ จะได้ศึกษาลำดับของการทำงานของคลาสในการสืบทอดสมบัติ
//
// โดยให้คอนสตรักเตอร์ของคลาสแต่ละระดับทำหน้าที่แสดงข้อความออกมาตามบลำดับการสร้าง object

// %% [markdown]
// ## แผนผังการสืบทอดสมบัติของคลาส

// %%
classDiagram
    class BaseClass1
    class BaseClass2
    class DerivedClass

    BaseClass1 <|-- DerivedClass
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="952d6abbac344df48fe596941feac30b"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('952d6abbac344df48fe596941feac30b');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_952d6abbac344df48fe596941feac30b',
//                     `classDiagram
//     class BaseClass1
//     class BaseClass2
//     class DerivedClass
//
//     BaseClass1 <|-- DerivedClass
//     `);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
//                 console.log(error);
//             }
// ...

// %% [markdown]
// จากแผนภาพคลาสไดอะแกรมด้านบน เราสามารถนำมาเขียนโปรแกรมในภาษา C# ได้ดังนี้

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex03
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// class BaseClass1
//  {
//     public BaseClass1()
//     {
//         System.Console.WriteLine("This is BaseClass1");
//     }
//  }
// class BaseClass2
//  {
//     public BaseClass2()
//     {
//         System.Console.WriteLine("This is BaseClass2");
//     }
//  }
//
// class DerivedClass : BaseClass1
// {
//     public DerivedClass()
//     {
//         System.Console.WriteLine("This is DerivedClass");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex03
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex03
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// เมื่อสร้างอ็อบเจ็กต์ของ DerivedClass (DerivedClass dc = new DerivedClass();)
//
// คอนสตรักเตอร์ของ BaseClass1 จะถูกเรียกก่อน
//
// จากนั้นคอนสตรักเตอร์ของ DerivedClass จะถูกเรียก

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. การที่มีคลาส BaseClass2 อยู่ใน source code นั้นมีผลใดๆ ต่อการทำงานของโปรแกรมหรือไม่

// %% [markdown]
// BaseClass2 อยู่ใน source code นั้น ไม่มีผลต่อการทำงานของโปรแกรมเมื่อใดที่คลาส BaseClass2 ไม่ได้ถูกเรียกใช้งาน ในโค้ดที่รันจริง

// %% [markdown]
// 2. ให้บอกลำดับการทำงานของคลาส ว่า constructor มีลำดับการเรียกอย่างไร (เรียก base class หรือ derive class ก่่อน)

// %% [markdown]
// จากโค้ดนี้ DerivedClass สืบทอดมาจาก BaseClass1 ดังนั้นเมื่อสร้างอ็อบเจ็กต์ dc ของ DerivedClass:
//
// Constructor ของ BaseClass1 จะถูกเรียกก่อน
//
// Constructor ของ DerivedClass จะถูกเรียกทีหลัง
