// %% [markdown]
// # Lab 12 Class Inheritance

// %% [markdown]
// ## Multiple base class inheritance

// %%
classDiagram
    class BaseClass1
    class BaseClass2
    class DerivedClass

    BaseClass1 <|-- BaseClass2
    BaseClass2 <|-- DerivedClass
// Out:
// <div class="mermaidMarkdownContainer" style="background-color:white">
// <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.2.0/css/all.min.css">
// <div id="2f250d1a7c754d0e882b27ba07ed19b8"></div>
// <script type="module">
//
//             import mermaid from 'https://cdn.jsdelivr.net/npm/mermaid@10.6.1/dist/mermaid.esm.min.mjs';
//             let renderTarget = document.getElementById('2f250d1a7c754d0e882b27ba07ed19b8');
//             try {
//                 const {svg, bindFunctions} = await mermaid.mermaidAPI.render(
//                     'mermaid_2f250d1a7c754d0e882b27ba07ed19b8',
//                     `classDiagram
//     class BaseClass1
//     class BaseClass2
//     class DerivedClass
//
//     BaseClass1 <|-- BaseClass2
//     BaseClass2 <|-- DerivedClass`);
//                 renderTarget.innerHTML = svg;
//                 bindFunctions?.(renderTarget);
//             }
//             catch (error) {
// ...

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab12_Ex06
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// DerivedClass dc = new DerivedClass();
// class BaseClass1
//  {
//     public BaseClass1()
//     {
//         System.Console.WriteLine("This is BaseClass1");
//     }
//  }
// class BaseClass2: BaseClass1
//  {
//     public BaseClass2()
//     {
//         System.Console.WriteLine("This is BaseClass2");
//     }
//  }
//
// class DerivedClass : BaseClass2
// {
//     public DerivedClass()
//     {
//         System.Console.WriteLine("This is DerivedClass");
//     }
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab12_Ex06
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab12_Ex06
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ใน C# การสืบทอดแบบหลายชั้น (multilevel inheritance) จะเรียก constructor ของคลาสที่สืบทอดจากฐาน (base class) ก่อน และจากนั้นจึงเรียก constructor ของคลาสที่สืบทอดมาจากมัน (derived class) ตามลำดับ
